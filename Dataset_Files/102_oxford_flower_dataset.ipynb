# %% [markdown]
# # Imports

# %%
import os
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import math
import shutil
import random
import csv

# %% [markdown]
# # Oxford Flower Image Dataset

# %%
# Paths
oxford_flower_dataset_path = '/Users/maggie/Desktop/project_3/Plant_ID_and_Diagnosis/Resources/plant_identifcation_resources/testflowers/dataset'
json_file_path = '/Users/maggie/Desktop/project_3/Plant_ID_and_Diagnosis/Resources/plant_identifcation_resources/testflowers/cat_to_name.json'
oxford_flowers_folder = '/Users/maggie/Desktop/project_3/Plant_ID_and_Diagnosis/Resources/plant_dr_master_dataset/102_oxford_flowers'
csv_file_path = os.path.join(oxford_flowers_folder, 'image_labels.csv')

# Ensure the output directory exists
os.makedirs(oxford_flowers_folder, exist_ok=True)

# %%
# Load the JSON file with category to name mappings
with open(json_file_path, 'r') as f:
    cat_to_name = json.load(f)

# Update the class names to replace spaces with underscores
cat_to_name = {key: value.replace(' ', '_') for key, value in cat_to_name.items()}

# Print a few sample mappings to inspect
for i, (key, value) in enumerate(cat_to_name.items()):
    if i < 10:
        print(f"Category ID: {key}, Class Name: {value}")
    else:
        break

# Function to rename folders and files with underscores
def replace_spaces_with_underscores(root_dir):
    for dirpath, dirnames, filenames in os.walk(root_dir, topdown=False):
        for filename in filenames:
            if ' ' in filename:
                new_filename = filename.replace(' ', '_')
                os.rename(os.path.join(dirpath, filename), os.path.join(dirpath, new_filename))
        for dirname in dirnames:
            if ' ' in dirname:
                new_dirname = dirname.replace(' ', '_')
                os.rename(os.path.join(dirpath, dirname), os.path.join(dirpath, new_dirname))

replace_spaces_with_underscores(oxford_flower_dataset_path)
# Out:
# Category ID: 21, Class Name: fire_lily
# Category ID: 3, Class Name: canterbury_bells
# Category ID: 45, Class Name: bolero_deep_blue
# Category ID: 1, Class Name: pink_primrose
# Category ID: 34, Class Name: mexican_aster
# Category ID: 27, Class Name: prince_of_wales_feathers
# Category ID: 7, Class Name: moon_orchid
# Category ID: 16, Class Name: globe-flower
# Category ID: 25, Class Name: grape_hyacinth
# Category ID: 26, Class Name: corn_poppy

# %%
# ImageDataGenerator setup
img_size = (128, 128)
datagen = ImageDataGenerator(rescale=1./255)

# Load training and validation data
train_generator = datagen.flow_from_directory(
    os.path.join(oxford_flower_dataset_path, 'train'),
    target_size=img_size,
    batch_size=32,
    class_mode='categorical'
)

# Print class indices to verify the mapping
print("Class indices:", train_generator.class_indices)
# Out:
# Found 6552 images belonging to 102 classes.
# Class indices: {'1': 0, '10': 1, '100': 2, '101': 3, '102': 4, '11': 5, '12': 6, '13': 7, '14': 8, '15': 9, '16': 10, '17': 11, '18': 12, '19': 13, '2': 14, '20': 15, '21': 16, '22': 17, '23': 18, '24': 19, '25': 20, '26': 21, '27': 22, '28': 23, '29': 24, '3': 25, '30': 26, '31': 27, '32': 28, '33': 29, '34': 30, '35': 31, '36': 32, '37': 33, '38': 34, '39': 35, '4': 36, '40': 37, '41': 38, '42': 39, '43': 40, '44': 41, '45': 42, '46': 43, '47': 44, '48': 45, '49': 46, '5': 47, '50': 48, '51': 49, '52': 50, '53': 51, '54': 52, '55': 53, '56': 54, '57': 55, '58': 56, '59': 57, '6': 58, '60': 59, '61': 60, '62': 61, '63': 62, '64': 63, '65': 64, '66': 65, '67': 66, '68': 67, '69': 68, '7': 69, '70': 70, '71': 71, '72': 72, '73': 73, '74': 74, '75': 75, '76': 76, '77': 77, '78': 78, '79': 79, '8': 80, '80': 81, '81': 82, '82': 83, '83': 84, '84': 85, '85': 86, '86': 87, '87': 88, '88': 89, '89': 90, '9': 91, '90': 92, '91': 93, '92': 94, '93': 95, '94': 96, '95': 97, '96': 98, '97': 99, '98': 100, '99': 101}

# %%
# Check existing entries in the CSV file to prevent duplicates
existing_filenames = set()
if os.path.exists(csv_file_path):
    with open(csv_file_path, mode='r') as csv_file:
        reader = csv.DictReader(csv_file)
        for row in reader:
            existing_filenames.add(row['filename'])

existing_filenames
# Out:
# set()

# %%
# Open the CSV file in the appropriate mode
with open(csv_file_path, mode='a' if existing_filenames else 'w', newline='') as csv_file:
    fieldnames = ['filename', 'label']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)
    
    # Write the header if the file is being created for the first time
    if not existing_filenames:
        writer.writeheader()

    # Iterate over the entire dataset using the data generator
    for batch_index in range(len(train_generator)):
        # Get a batch of images and labels
        images, labels = next(train_generator)

        # Loop through the images and labels to save them with correct filenames
        for i in range(len(images)):
            # Get the image array and convert it to a PIL Image
            image_array = images[i]
            image = Image.fromarray((image_array * 255).astype('uint8'))  # Convert from normalized to pixel values if needed

            # Get the class index and map it to the correct class name
            class_index = labels[i].argmax()  # Find the class index
            class_name = list(train_generator.class_indices.keys())[class_index]

            # Map the class name to the human-readable label using the JSON file
            human_readable_label = cat_to_name.get(class_name, "Unknown")
            
            # Append "_healthy" to the label if necessary
            if "healthy" in human_readable_label.lower():
                human_readable_label += "_healthy"

            # Define the file name and save path
            filename = f"{human_readable_label}_{batch_index}_{i+1}.jpg"
            save_path = os.path.join(oxford_flowers_folder, filename)

            # Check if the file already exists
            if filename not in existing_filenames:
                # Save the image
                image.save(save_path)

                # Write the filename and label to the CSV file
                writer.writerow({'filename': filename, 'label': human_readable_label})

                print(f"Saved image {filename} and wrote to CSV with label {human_readable_label}")
            else:
                print(f"Skipped existing image {filename}")
# Out:
# Saved image water_lily_0_1.jpg and wrote to CSV with label water_lily
# Saved image great_masterwort_0_2.jpg and wrote to CSV with label great_masterwort
# Saved image wallflower_0_3.jpg and wrote to CSV with label wallflower
# Saved image rose_0_4.jpg and wrote to CSV with label rose
# Saved image sword_lily_0_5.jpg and wrote to CSV with label sword_lily
# Saved image water_lily_0_6.jpg and wrote to CSV with label water_lily
# Saved image azalea_0_7.jpg and wrote to CSV with label azalea
# Saved image osteospermum_0_8.jpg and wrote to CSV with label osteospermum
# Saved image pink-yellow_dahlia_0_9.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image morning_glory_0_10.jpg and wrote to CSV with label morning_glory
# Saved image desert-rose_0_11.jpg and wrote to CSV with label desert-rose
# Saved image windflower_0_12.jpg and wrote to CSV with label windflower
# Saved image balloon_flower_0_13.jpg and wrote to CSV with label balloon_flower
# Saved image tree_poppy_0_14.jpg and wrote to CSV with label tree_poppy
# Saved image blackberry_lily_0_15.jpg and wrote to CSV with label blackberry_lily
# Saved image water_lily_0_16.jpg and wrote to CSV with label water_lily
# Saved image snapdragon_0_17.jpg and wrote to CSV with label snapdragon
# Saved image bird_of_paradise_0_18.jpg and wrote to CSV with label bird_of_paradise
# Saved image petunia_0_19.jpg and wrote to CSV with label petunia
# Saved image snapdragon_0_20.jpg and wrote to CSV with label snapdragon
# Saved image purple_coneflower_0_21.jpg and wrote to CSV with label purple_coneflower
# Saved image passion_flower_0_22.jpg and wrote to CSV with label passion_flower
# Saved image californian_poppy_0_23.jpg and wrote to CSV with label californian_poppy
# Saved image bee_balm_0_24.jpg and wrote to CSV with label bee_balm
# Saved image water_lily_0_25.jpg and wrote to CSV with label water_lily
# Saved image tree_poppy_0_26.jpg and wrote to CSV with label tree_poppy
# Saved image frangipani_0_27.jpg and wrote to CSV with label frangipani
# Saved image osteospermum_0_28.jpg and wrote to CSV with label osteospermum
# Saved image toad_lily_0_29.jpg and wrote to CSV with label toad_lily
# Saved image orange_dahlia_0_30.jpg and wrote to CSV with label orange_dahlia
# Saved image red_ginger_0_31.jpg and wrote to CSV with label red_ginger
# Saved image petunia_0_32.jpg and wrote to CSV with label petunia
# Saved image orange_dahlia_1_1.jpg and wrote to CSV with label orange_dahlia
# Saved image sword_lily_1_2.jpg and wrote to CSV with label sword_lily
# Saved image carnation_1_3.jpg and wrote to CSV with label carnation
# Saved image thorn_apple_1_4.jpg and wrote to CSV with label thorn_apple
# Saved image king_protea_1_5.jpg and wrote to CSV with label king_protea
# Saved image gazania_1_6.jpg and wrote to CSV with label gazania
# Saved image cyclamen_1_7.jpg and wrote to CSV with label cyclamen
# Saved image wallflower_1_8.jpg and wrote to CSV with label wallflower
# Saved image pink-yellow_dahlia_1_9.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image watercress_1_10.jpg and wrote to CSV with label watercress
# Saved image water_lily_1_11.jpg and wrote to CSV with label water_lily
# Saved image giant_white_arum_lily_1_12.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image garden_phlox_1_13.jpg and wrote to CSV with label garden_phlox
# Saved image gaura_1_14.jpg and wrote to CSV with label gaura
# Saved image bishop_of_llandaff_1_15.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image black-eyed_susan_1_16.jpg and wrote to CSV with label black-eyed_susan
# Saved image lotus_lotus_1_17.jpg and wrote to CSV with label lotus_lotus
# Saved image english_marigold_1_18.jpg and wrote to CSV with label english_marigold
# Saved image ball_moss_1_19.jpg and wrote to CSV with label ball_moss
# Saved image thorn_apple_1_20.jpg and wrote to CSV with label thorn_apple
# Saved image ruby-lipped_cattleya_1_21.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image stemless_gentian_1_22.jpg and wrote to CSV with label stemless_gentian
# Saved image fritillary_1_23.jpg and wrote to CSV with label fritillary
# Saved image thorn_apple_1_24.jpg and wrote to CSV with label thorn_apple
# Saved image passion_flower_1_25.jpg and wrote to CSV with label passion_flower
# Saved image garden_phlox_1_26.jpg and wrote to CSV with label garden_phlox
# Saved image rose_1_27.jpg and wrote to CSV with label rose
# Saved image poinsettia_1_28.jpg and wrote to CSV with label poinsettia
# Saved image lenten_rose_1_29.jpg and wrote to CSV with label lenten_rose
# Saved image orange_dahlia_1_30.jpg and wrote to CSV with label orange_dahlia
# Saved image primula_1_31.jpg and wrote to CSV with label primula
# Saved image carnation_1_32.jpg and wrote to CSV with label carnation
# Saved image foxglove_2_1.jpg and wrote to CSV with label foxglove
# Saved image barbeton_daisy_2_2.jpg and wrote to CSV with label barbeton_daisy
# Saved image frangipani_2_3.jpg and wrote to CSV with label frangipani
# Saved image alpine_sea_holly_2_4.jpg and wrote to CSV with label alpine_sea_holly
# Saved image petunia_2_5.jpg and wrote to CSV with label petunia
# Saved image bearded_iris_2_6.jpg and wrote to CSV with label bearded_iris
# Saved image common_dandelion_2_7.jpg and wrote to CSV with label common_dandelion
# Saved image frangipani_2_8.jpg and wrote to CSV with label frangipani
# Saved image barbeton_daisy_2_9.jpg and wrote to CSV with label barbeton_daisy
# Saved image sweet_william_2_10.jpg and wrote to CSV with label sweet_william
# Saved image watercress_2_11.jpg and wrote to CSV with label watercress
# Saved image barbeton_daisy_2_12.jpg and wrote to CSV with label barbeton_daisy
# Saved image love_in_the_mist_2_13.jpg and wrote to CSV with label love_in_the_mist
# Saved image hibiscus_2_14.jpg and wrote to CSV with label hibiscus
# Saved image geranium_2_15.jpg and wrote to CSV with label geranium
# Saved image cape_flower_2_16.jpg and wrote to CSV with label cape_flower
# Saved image azalea_2_17.jpg and wrote to CSV with label azalea
# Saved image passion_flower_2_18.jpg and wrote to CSV with label passion_flower
# Saved image hibiscus_2_19.jpg and wrote to CSV with label hibiscus
# Saved image rose_2_20.jpg and wrote to CSV with label rose
# Saved image watercress_2_21.jpg and wrote to CSV with label watercress
# Saved image petunia_2_22.jpg and wrote to CSV with label petunia
# Saved image azalea_2_23.jpg and wrote to CSV with label azalea
# Saved image toad_lily_2_24.jpg and wrote to CSV with label toad_lily
# Saved image desert-rose_2_25.jpg and wrote to CSV with label desert-rose
# Saved image bromelia_2_26.jpg and wrote to CSV with label bromelia
# Saved image globe-flower_2_27.jpg and wrote to CSV with label globe-flower
# Saved image red_ginger_2_28.jpg and wrote to CSV with label red_ginger
# Saved image cyclamen_2_29.jpg and wrote to CSV with label cyclamen
# Saved image geranium_2_30.jpg and wrote to CSV with label geranium
# Saved image cape_flower_2_31.jpg and wrote to CSV with label cape_flower
# Saved image mexican_petunia_2_32.jpg and wrote to CSV with label mexican_petunia
# Saved image passion_flower_3_1.jpg and wrote to CSV with label passion_flower
# Saved image corn_poppy_3_2.jpg and wrote to CSV with label corn_poppy
# Saved image watercress_3_3.jpg and wrote to CSV with label watercress
# Saved image californian_poppy_3_4.jpg and wrote to CSV with label californian_poppy
# Saved image geranium_3_5.jpg and wrote to CSV with label geranium
# Saved image columbine_3_6.jpg and wrote to CSV with label columbine
# Saved image camellia_3_7.jpg and wrote to CSV with label camellia
# Saved image spear_thistle_3_8.jpg and wrote to CSV with label spear_thistle
# Saved image mallow_3_9.jpg and wrote to CSV with label mallow
# Saved image common_dandelion_3_10.jpg and wrote to CSV with label common_dandelion
# Saved image bougainvillea_3_11.jpg and wrote to CSV with label bougainvillea
# Saved image king_protea_3_12.jpg and wrote to CSV with label king_protea
# Saved image wallflower_3_13.jpg and wrote to CSV with label wallflower
# Saved image frangipani_3_14.jpg and wrote to CSV with label frangipani
# Saved image watercress_3_15.jpg and wrote to CSV with label watercress
# Saved image globe-flower_3_16.jpg and wrote to CSV with label globe-flower
# Saved image rose_3_17.jpg and wrote to CSV with label rose
# Saved image desert-rose_3_18.jpg and wrote to CSV with label desert-rose
# Saved image californian_poppy_3_19.jpg and wrote to CSV with label californian_poppy
# Saved image hibiscus_3_20.jpg and wrote to CSV with label hibiscus
# Saved image peruvian_lily_3_21.jpg and wrote to CSV with label peruvian_lily
# Saved image magnolia_3_22.jpg and wrote to CSV with label magnolia
# Saved image prince_of_wales_feathers_3_23.jpg and wrote to CSV with label prince_of_wales_feathers
# Saved image orange_dahlia_3_24.jpg and wrote to CSV with label orange_dahlia
# Saved image snapdragon_3_25.jpg and wrote to CSV with label snapdragon
# Saved image wallflower_3_26.jpg and wrote to CSV with label wallflower
# Saved image frangipani_3_27.jpg and wrote to CSV with label frangipani
# Saved image bishop_of_llandaff_3_28.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image clematis_3_29.jpg and wrote to CSV with label clematis
# Saved image english_marigold_3_30.jpg and wrote to CSV with label english_marigold
# Saved image wallflower_3_31.jpg and wrote to CSV with label wallflower
# Saved image rose_3_32.jpg and wrote to CSV with label rose
# Saved image bougainvillea_4_1.jpg and wrote to CSV with label bougainvillea
# Saved image rose_4_2.jpg and wrote to CSV with label rose
# Saved image blanket_flower_4_3.jpg and wrote to CSV with label blanket_flower
# Saved image bird_of_paradise_4_4.jpg and wrote to CSV with label bird_of_paradise
# Saved image watercress_4_5.jpg and wrote to CSV with label watercress
# Saved image siam_tulip_4_6.jpg and wrote to CSV with label siam_tulip
# Saved image corn_poppy_4_7.jpg and wrote to CSV with label corn_poppy
# Saved image passion_flower_4_8.jpg and wrote to CSV with label passion_flower
# Saved image morning_glory_4_9.jpg and wrote to CSV with label morning_glory
# Saved image sword_lily_4_10.jpg and wrote to CSV with label sword_lily
# Saved image blanket_flower_4_11.jpg and wrote to CSV with label blanket_flower
# Saved image globe-flower_4_12.jpg and wrote to CSV with label globe-flower
# Saved image barbeton_daisy_4_13.jpg and wrote to CSV with label barbeton_daisy
# Saved image frangipani_4_14.jpg and wrote to CSV with label frangipani
# Saved image poinsettia_4_15.jpg and wrote to CSV with label poinsettia
# Saved image columbine_4_16.jpg and wrote to CSV with label columbine
# Saved image thorn_apple_4_17.jpg and wrote to CSV with label thorn_apple
# Saved image japanese_anemone_4_18.jpg and wrote to CSV with label japanese_anemone
# Saved image sweet_pea_4_19.jpg and wrote to CSV with label sweet_pea
# Saved image daffodil_4_20.jpg and wrote to CSV with label daffodil
# Saved image wallflower_4_21.jpg and wrote to CSV with label wallflower
# Saved image barbeton_daisy_4_22.jpg and wrote to CSV with label barbeton_daisy
# Saved image water_lily_4_23.jpg and wrote to CSV with label water_lily
# Saved image bougainvillea_4_24.jpg and wrote to CSV with label bougainvillea
# Saved image poinsettia_4_25.jpg and wrote to CSV with label poinsettia
# Saved image frangipani_4_26.jpg and wrote to CSV with label frangipani
# Saved image cautleya_spicata_4_27.jpg and wrote to CSV with label cautleya_spicata
# Saved image japanese_anemone_4_28.jpg and wrote to CSV with label japanese_anemone
# Saved image camellia_4_29.jpg and wrote to CSV with label camellia
# Saved image siam_tulip_4_30.jpg and wrote to CSV with label siam_tulip
# Saved image daffodil_4_31.jpg and wrote to CSV with label daffodil
# Saved image watercress_4_32.jpg and wrote to CSV with label watercress
# Saved image english_marigold_5_1.jpg and wrote to CSV with label english_marigold
# Saved image love_in_the_mist_5_2.jpg and wrote to CSV with label love_in_the_mist
# Saved image lotus_lotus_5_3.jpg and wrote to CSV with label lotus_lotus
# Saved image wallflower_5_4.jpg and wrote to CSV with label wallflower
# Saved image hippeastrum_5_5.jpg and wrote to CSV with label hippeastrum
# Saved image camellia_5_6.jpg and wrote to CSV with label camellia
# Saved image daffodil_5_7.jpg and wrote to CSV with label daffodil
# Saved image oxeye_daisy_5_8.jpg and wrote to CSV with label oxeye_daisy
# Saved image hard-leaved_pocket_orchid_5_9.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image foxglove_5_10.jpg and wrote to CSV with label foxglove
# Saved image clematis_5_11.jpg and wrote to CSV with label clematis
# Saved image oxeye_daisy_5_12.jpg and wrote to CSV with label oxeye_daisy
# Saved image water_lily_5_13.jpg and wrote to CSV with label water_lily
# Saved image foxglove_5_14.jpg and wrote to CSV with label foxglove
# Saved image mexican_petunia_5_15.jpg and wrote to CSV with label mexican_petunia
# Saved image wallflower_5_16.jpg and wrote to CSV with label wallflower
# Saved image grape_hyacinth_5_17.jpg and wrote to CSV with label grape_hyacinth
# Saved image lenten_rose_5_18.jpg and wrote to CSV with label lenten_rose
# Saved image desert-rose_5_19.jpg and wrote to CSV with label desert-rose
# Saved image mallow_5_20.jpg and wrote to CSV with label mallow
# Saved image petunia_5_21.jpg and wrote to CSV with label petunia
# Saved image yellow_iris_5_22.jpg and wrote to CSV with label yellow_iris
# Saved image garden_phlox_5_23.jpg and wrote to CSV with label garden_phlox
# Saved image water_lily_5_24.jpg and wrote to CSV with label water_lily
# Saved image watercress_5_25.jpg and wrote to CSV with label watercress
# Saved image frangipani_5_26.jpg and wrote to CSV with label frangipani
# Saved image thorn_apple_5_27.jpg and wrote to CSV with label thorn_apple
# Saved image love_in_the_mist_5_28.jpg and wrote to CSV with label love_in_the_mist
# Saved image canna_lily_5_29.jpg and wrote to CSV with label canna_lily
# Saved image camellia_5_30.jpg and wrote to CSV with label camellia
# Saved image bishop_of_llandaff_5_31.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image canterbury_bells_5_32.jpg and wrote to CSV with label canterbury_bells
# Saved image wallflower_6_1.jpg and wrote to CSV with label wallflower
# Saved image bird_of_paradise_6_2.jpg and wrote to CSV with label bird_of_paradise
# Saved image morning_glory_6_3.jpg and wrote to CSV with label morning_glory
# Saved image wallflower_6_4.jpg and wrote to CSV with label wallflower
# Saved image rose_6_5.jpg and wrote to CSV with label rose
# Saved image morning_glory_6_6.jpg and wrote to CSV with label morning_glory
# Saved image foxglove_6_7.jpg and wrote to CSV with label foxglove
# Saved image monkshood_6_8.jpg and wrote to CSV with label monkshood
# Saved image common_dandelion_6_9.jpg and wrote to CSV with label common_dandelion
# Saved image pink-yellow_dahlia_6_10.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image fire_lily_6_11.jpg and wrote to CSV with label fire_lily
# Saved image petunia_6_12.jpg and wrote to CSV with label petunia
# Saved image daffodil_6_13.jpg and wrote to CSV with label daffodil
# Saved image californian_poppy_6_14.jpg and wrote to CSV with label californian_poppy
# Saved image petunia_6_15.jpg and wrote to CSV with label petunia
# Saved image watercress_6_16.jpg and wrote to CSV with label watercress
# Saved image japanese_anemone_6_17.jpg and wrote to CSV with label japanese_anemone
# Saved image bearded_iris_6_18.jpg and wrote to CSV with label bearded_iris
# Saved image hippeastrum_6_19.jpg and wrote to CSV with label hippeastrum
# Saved image petunia_6_20.jpg and wrote to CSV with label petunia
# Saved image lotus_lotus_6_21.jpg and wrote to CSV with label lotus_lotus
# Saved image gazania_6_22.jpg and wrote to CSV with label gazania
# Saved image frangipani_6_23.jpg and wrote to CSV with label frangipani
# Saved image columbine_6_24.jpg and wrote to CSV with label columbine
# Saved image wallflower_6_25.jpg and wrote to CSV with label wallflower
# Saved image lotus_lotus_6_26.jpg and wrote to CSV with label lotus_lotus
# Saved image cape_flower_6_27.jpg and wrote to CSV with label cape_flower
# Saved image frangipani_6_28.jpg and wrote to CSV with label frangipani
# Saved image bearded_iris_6_29.jpg and wrote to CSV with label bearded_iris
# Saved image blanket_flower_6_30.jpg and wrote to CSV with label blanket_flower
# Saved image buttercup_6_31.jpg and wrote to CSV with label buttercup
# Saved image water_lily_6_32.jpg and wrote to CSV with label water_lily
# Saved image cautleya_spicata_7_1.jpg and wrote to CSV with label cautleya_spicata
# Saved image poinsettia_7_2.jpg and wrote to CSV with label poinsettia
# Saved image mallow_7_3.jpg and wrote to CSV with label mallow
# Saved image daffodil_7_4.jpg and wrote to CSV with label daffodil
# Saved image pincushion_flower_7_5.jpg and wrote to CSV with label pincushion_flower
# Saved image bougainvillea_7_6.jpg and wrote to CSV with label bougainvillea
# Saved image hibiscus_7_7.jpg and wrote to CSV with label hibiscus
# Saved image passion_flower_7_8.jpg and wrote to CSV with label passion_flower
# Saved image cape_flower_7_9.jpg and wrote to CSV with label cape_flower
# Saved image toad_lily_7_10.jpg and wrote to CSV with label toad_lily
# Saved image petunia_7_11.jpg and wrote to CSV with label petunia
# Saved image buttercup_7_12.jpg and wrote to CSV with label buttercup
# Saved image water_lily_7_13.jpg and wrote to CSV with label water_lily
# Saved image buttercup_7_14.jpg and wrote to CSV with label buttercup
# Saved image thorn_apple_7_15.jpg and wrote to CSV with label thorn_apple
# Saved image bromelia_7_16.jpg and wrote to CSV with label bromelia
# Saved image californian_poppy_7_17.jpg and wrote to CSV with label californian_poppy
# Saved image spear_thistle_7_18.jpg and wrote to CSV with label spear_thistle
# Saved image clematis_7_19.jpg and wrote to CSV with label clematis
# Saved image sweet_william_7_20.jpg and wrote to CSV with label sweet_william
# Saved image foxglove_7_21.jpg and wrote to CSV with label foxglove
# Saved image bougainvillea_7_22.jpg and wrote to CSV with label bougainvillea
# Saved image fritillary_7_23.jpg and wrote to CSV with label fritillary
# Saved image peruvian_lily_7_24.jpg and wrote to CSV with label peruvian_lily
# Saved image marigold_7_25.jpg and wrote to CSV with label marigold
# Saved image water_lily_7_26.jpg and wrote to CSV with label water_lily
# Saved image bird_of_paradise_7_27.jpg and wrote to CSV with label bird_of_paradise
# Saved image ruby-lipped_cattleya_7_28.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image marigold_7_29.jpg and wrote to CSV with label marigold
# Saved image geranium_7_30.jpg and wrote to CSV with label geranium
# Saved image bougainvillea_7_31.jpg and wrote to CSV with label bougainvillea
# Saved image blanket_flower_7_32.jpg and wrote to CSV with label blanket_flower
# Saved image globe-flower_8_1.jpg and wrote to CSV with label globe-flower
# Saved image spear_thistle_8_2.jpg and wrote to CSV with label spear_thistle
# Saved image frangipani_8_3.jpg and wrote to CSV with label frangipani
# Saved image silverbush_8_4.jpg and wrote to CSV with label silverbush
# Saved image foxglove_8_5.jpg and wrote to CSV with label foxglove
# Saved image bishop_of_llandaff_8_6.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image lotus_lotus_8_7.jpg and wrote to CSV with label lotus_lotus
# Saved image rose_8_8.jpg and wrote to CSV with label rose
# Saved image giant_white_arum_lily_8_9.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image pink-yellow_dahlia_8_10.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image anthurium_8_11.jpg and wrote to CSV with label anthurium
# Saved image bougainvillea_8_12.jpg and wrote to CSV with label bougainvillea
# Saved image bougainvillea_8_13.jpg and wrote to CSV with label bougainvillea
# Saved image petunia_8_14.jpg and wrote to CSV with label petunia
# Saved image orange_dahlia_8_15.jpg and wrote to CSV with label orange_dahlia
# Saved image primula_8_16.jpg and wrote to CSV with label primula
# Saved image wallflower_8_17.jpg and wrote to CSV with label wallflower
# Saved image bearded_iris_8_18.jpg and wrote to CSV with label bearded_iris
# Saved image trumpet_creeper_8_19.jpg and wrote to CSV with label trumpet_creeper
# Saved image peruvian_lily_8_20.jpg and wrote to CSV with label peruvian_lily
# Saved image wallflower_8_21.jpg and wrote to CSV with label wallflower
# Saved image camellia_8_22.jpg and wrote to CSV with label camellia
# Saved image poinsettia_8_23.jpg and wrote to CSV with label poinsettia
# Saved image watercress_8_24.jpg and wrote to CSV with label watercress
# Saved image frangipani_8_25.jpg and wrote to CSV with label frangipani
# Saved image camellia_8_26.jpg and wrote to CSV with label camellia
# Saved image clematis_8_27.jpg and wrote to CSV with label clematis
# Saved image pelargonium_8_28.jpg and wrote to CSV with label pelargonium
# Saved image rose_8_29.jpg and wrote to CSV with label rose
# Saved image barbeton_daisy_8_30.jpg and wrote to CSV with label barbeton_daisy
# Saved image spring_crocus_8_31.jpg and wrote to CSV with label spring_crocus
# Saved image ruby-lipped_cattleya_8_32.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image peruvian_lily_9_1.jpg and wrote to CSV with label peruvian_lily
# Saved image passion_flower_9_2.jpg and wrote to CSV with label passion_flower
# Saved image frangipani_9_3.jpg and wrote to CSV with label frangipani
# Saved image oxeye_daisy_9_4.jpg and wrote to CSV with label oxeye_daisy
# Saved image morning_glory_9_5.jpg and wrote to CSV with label morning_glory
# Saved image foxglove_9_6.jpg and wrote to CSV with label foxglove
# Saved image mexican_petunia_9_7.jpg and wrote to CSV with label mexican_petunia
# Saved image bougainvillea_9_8.jpg and wrote to CSV with label bougainvillea
# Saved image azalea_9_9.jpg and wrote to CSV with label azalea
# Saved image barbeton_daisy_9_10.jpg and wrote to CSV with label barbeton_daisy
# Saved image azalea_9_11.jpg and wrote to CSV with label azalea
# Saved image rose_9_12.jpg and wrote to CSV with label rose
# Saved image peruvian_lily_9_13.jpg and wrote to CSV with label peruvian_lily
# Saved image sword_lily_9_14.jpg and wrote to CSV with label sword_lily
# Saved image sweet_william_9_15.jpg and wrote to CSV with label sweet_william
# Saved image japanese_anemone_9_16.jpg and wrote to CSV with label japanese_anemone
# Saved image petunia_9_17.jpg and wrote to CSV with label petunia
# Saved image blackberry_lily_9_18.jpg and wrote to CSV with label blackberry_lily
# Saved image water_lily_9_19.jpg and wrote to CSV with label water_lily
# Saved image great_masterwort_9_20.jpg and wrote to CSV with label great_masterwort
# Saved image lotus_lotus_9_21.jpg and wrote to CSV with label lotus_lotus
# Saved image californian_poppy_9_22.jpg and wrote to CSV with label californian_poppy
# Saved image peruvian_lily_9_23.jpg and wrote to CSV with label peruvian_lily
# Saved image foxglove_9_24.jpg and wrote to CSV with label foxglove
# Saved image cape_flower_9_25.jpg and wrote to CSV with label cape_flower
# Saved image frangipani_9_26.jpg and wrote to CSV with label frangipani
# Saved image bishop_of_llandaff_9_27.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image frangipani_9_28.jpg and wrote to CSV with label frangipani
# Saved image wallflower_9_29.jpg and wrote to CSV with label wallflower
# Saved image watercress_9_30.jpg and wrote to CSV with label watercress
# Saved image gaura_9_31.jpg and wrote to CSV with label gaura
# Saved image petunia_9_32.jpg and wrote to CSV with label petunia
# Saved image hippeastrum_10_1.jpg and wrote to CSV with label hippeastrum
# Saved image corn_poppy_10_2.jpg and wrote to CSV with label corn_poppy
# Saved image petunia_10_3.jpg and wrote to CSV with label petunia
# Saved image morning_glory_10_4.jpg and wrote to CSV with label morning_glory
# Saved image watercress_10_5.jpg and wrote to CSV with label watercress
# Saved image black-eyed_susan_10_6.jpg and wrote to CSV with label black-eyed_susan
# Saved image pink-yellow_dahlia_10_7.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image sweet_pea_10_8.jpg and wrote to CSV with label sweet_pea
# Saved image californian_poppy_10_9.jpg and wrote to CSV with label californian_poppy
# Saved image petunia_10_10.jpg and wrote to CSV with label petunia
# Saved image daffodil_10_11.jpg and wrote to CSV with label daffodil
# Saved image columbine_10_12.jpg and wrote to CSV with label columbine
# Saved image rose_10_13.jpg and wrote to CSV with label rose
# Saved image yellow_iris_10_14.jpg and wrote to CSV with label yellow_iris
# Saved image water_lily_10_15.jpg and wrote to CSV with label water_lily
# Saved image snapdragon_10_16.jpg and wrote to CSV with label snapdragon
# Saved image bird_of_paradise_10_17.jpg and wrote to CSV with label bird_of_paradise
# Saved image primula_10_18.jpg and wrote to CSV with label primula
# Saved image water_lily_10_19.jpg and wrote to CSV with label water_lily
# Saved image sweet_pea_10_20.jpg and wrote to CSV with label sweet_pea
# Saved image cyclamen_10_21.jpg and wrote to CSV with label cyclamen
# Saved image cyclamen_10_22.jpg and wrote to CSV with label cyclamen
# Saved image mexican_petunia_10_23.jpg and wrote to CSV with label mexican_petunia
# Saved image mexican_aster_10_24.jpg and wrote to CSV with label mexican_aster
# Saved image camellia_10_25.jpg and wrote to CSV with label camellia
# Saved image bolero_deep_blue_10_26.jpg and wrote to CSV with label bolero_deep_blue
# Saved image wallflower_10_27.jpg and wrote to CSV with label wallflower
# Saved image thorn_apple_10_28.jpg and wrote to CSV with label thorn_apple
# Saved image canterbury_bells_10_29.jpg and wrote to CSV with label canterbury_bells
# Saved image sword_lily_10_30.jpg and wrote to CSV with label sword_lily
# Saved image japanese_anemone_10_31.jpg and wrote to CSV with label japanese_anemone
# Saved image petunia_10_32.jpg and wrote to CSV with label petunia
# Saved image king_protea_11_1.jpg and wrote to CSV with label king_protea
# Saved image bromelia_11_2.jpg and wrote to CSV with label bromelia
# Saved image columbine_11_3.jpg and wrote to CSV with label columbine
# Saved image hard-leaved_pocket_orchid_11_4.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image fritillary_11_5.jpg and wrote to CSV with label fritillary
# Saved image passion_flower_11_6.jpg and wrote to CSV with label passion_flower
# Saved image japanese_anemone_11_7.jpg and wrote to CSV with label japanese_anemone
# Saved image siam_tulip_11_8.jpg and wrote to CSV with label siam_tulip
# Saved image bromelia_11_9.jpg and wrote to CSV with label bromelia
# Saved image watercress_11_10.jpg and wrote to CSV with label watercress
# Saved image petunia_11_11.jpg and wrote to CSV with label petunia
# Saved image water_lily_11_12.jpg and wrote to CSV with label water_lily
# Saved image orange_dahlia_11_13.jpg and wrote to CSV with label orange_dahlia
# Saved image king_protea_11_14.jpg and wrote to CSV with label king_protea
# Saved image barbeton_daisy_11_15.jpg and wrote to CSV with label barbeton_daisy
# Saved image rose_11_16.jpg and wrote to CSV with label rose
# Saved image king_protea_11_17.jpg and wrote to CSV with label king_protea
# Saved image pincushion_flower_11_18.jpg and wrote to CSV with label pincushion_flower
# Saved image cape_flower_11_19.jpg and wrote to CSV with label cape_flower
# Saved image petunia_11_20.jpg and wrote to CSV with label petunia
# Saved image gazania_11_21.jpg and wrote to CSV with label gazania
# Saved image wild_pansy_11_22.jpg and wrote to CSV with label wild_pansy
# Saved image blackberry_lily_11_23.jpg and wrote to CSV with label blackberry_lily
# Saved image common_dandelion_11_24.jpg and wrote to CSV with label common_dandelion
# Saved image bolero_deep_blue_11_25.jpg and wrote to CSV with label bolero_deep_blue
# Saved image water_lily_11_26.jpg and wrote to CSV with label water_lily
# Saved image rose_11_27.jpg and wrote to CSV with label rose
# Saved image foxglove_11_28.jpg and wrote to CSV with label foxglove
# Saved image watercress_11_29.jpg and wrote to CSV with label watercress
# Saved image bee_balm_11_30.jpg and wrote to CSV with label bee_balm
# Saved image anthurium_11_31.jpg and wrote to CSV with label anthurium
# Saved image sword_lily_11_32.jpg and wrote to CSV with label sword_lily
# Saved image sword_lily_12_1.jpg and wrote to CSV with label sword_lily
# Saved image camellia_12_2.jpg and wrote to CSV with label camellia
# Saved image passion_flower_12_3.jpg and wrote to CSV with label passion_flower
# Saved image bee_balm_12_4.jpg and wrote to CSV with label bee_balm
# Saved image silverbush_12_5.jpg and wrote to CSV with label silverbush
# Saved image barbeton_daisy_12_6.jpg and wrote to CSV with label barbeton_daisy
# Saved image corn_poppy_12_7.jpg and wrote to CSV with label corn_poppy
# Saved image rose_12_8.jpg and wrote to CSV with label rose
# Saved image trumpet_creeper_12_9.jpg and wrote to CSV with label trumpet_creeper
# Saved image clematis_12_10.jpg and wrote to CSV with label clematis
# Saved image bougainvillea_12_11.jpg and wrote to CSV with label bougainvillea
# Saved image water_lily_12_12.jpg and wrote to CSV with label water_lily
# Saved image azalea_12_13.jpg and wrote to CSV with label azalea
# Saved image pink-yellow_dahlia_12_14.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image passion_flower_12_15.jpg and wrote to CSV with label passion_flower
# Saved image wild_pansy_12_16.jpg and wrote to CSV with label wild_pansy
# Saved image watercress_12_17.jpg and wrote to CSV with label watercress
# Saved image trumpet_creeper_12_18.jpg and wrote to CSV with label trumpet_creeper
# Saved image stemless_gentian_12_19.jpg and wrote to CSV with label stemless_gentian
# Saved image lotus_lotus_12_20.jpg and wrote to CSV with label lotus_lotus
# Saved image cyclamen_12_21.jpg and wrote to CSV with label cyclamen
# Saved image rose_12_22.jpg and wrote to CSV with label rose
# Saved image black-eyed_susan_12_23.jpg and wrote to CSV with label black-eyed_susan
# Saved image wild_pansy_12_24.jpg and wrote to CSV with label wild_pansy
# Saved image bishop_of_llandaff_12_25.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image fritillary_12_26.jpg and wrote to CSV with label fritillary
# Saved image passion_flower_12_27.jpg and wrote to CSV with label passion_flower
# Saved image passion_flower_12_28.jpg and wrote to CSV with label passion_flower
# Saved image osteospermum_12_29.jpg and wrote to CSV with label osteospermum
# Saved image wallflower_12_30.jpg and wrote to CSV with label wallflower
# Saved image lotus_lotus_12_31.jpg and wrote to CSV with label lotus_lotus
# Saved image water_lily_12_32.jpg and wrote to CSV with label water_lily
# Saved image english_marigold_13_1.jpg and wrote to CSV with label english_marigold
# Saved image fritillary_13_2.jpg and wrote to CSV with label fritillary
# Saved image sweet_william_13_3.jpg and wrote to CSV with label sweet_william
# Saved image mallow_13_4.jpg and wrote to CSV with label mallow
# Saved image pink_primrose_13_5.jpg and wrote to CSV with label pink_primrose
# Saved image fritillary_13_6.jpg and wrote to CSV with label fritillary
# Saved image sword_lily_13_7.jpg and wrote to CSV with label sword_lily
# Saved image orange_dahlia_13_8.jpg and wrote to CSV with label orange_dahlia
# Saved image mallow_13_9.jpg and wrote to CSV with label mallow
# Saved image black-eyed_susan_13_10.jpg and wrote to CSV with label black-eyed_susan
# Saved image water_lily_13_11.jpg and wrote to CSV with label water_lily
# Saved image osteospermum_13_12.jpg and wrote to CSV with label osteospermum
# Saved image clematis_13_13.jpg and wrote to CSV with label clematis
# Saved image marigold_13_14.jpg and wrote to CSV with label marigold
# Saved image desert-rose_13_15.jpg and wrote to CSV with label desert-rose
# Saved image clematis_13_16.jpg and wrote to CSV with label clematis
# Saved image passion_flower_13_17.jpg and wrote to CSV with label passion_flower
# Saved image sunflower_13_18.jpg and wrote to CSV with label sunflower
# Saved image purple_coneflower_13_19.jpg and wrote to CSV with label purple_coneflower
# Saved image cyclamen_13_20.jpg and wrote to CSV with label cyclamen
# Saved image tree_mallow_13_21.jpg and wrote to CSV with label tree_mallow
# Saved image globe-flower_13_22.jpg and wrote to CSV with label globe-flower
# Saved image frangipani_13_23.jpg and wrote to CSV with label frangipani
# Saved image wallflower_13_24.jpg and wrote to CSV with label wallflower
# Saved image bishop_of_llandaff_13_25.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image cape_flower_13_26.jpg and wrote to CSV with label cape_flower
# Saved image watercress_13_27.jpg and wrote to CSV with label watercress
# Saved image pelargonium_13_28.jpg and wrote to CSV with label pelargonium
# Saved image watercress_13_29.jpg and wrote to CSV with label watercress
# Saved image great_masterwort_13_30.jpg and wrote to CSV with label great_masterwort
# Saved image sweet_william_13_31.jpg and wrote to CSV with label sweet_william
# Saved image spear_thistle_13_32.jpg and wrote to CSV with label spear_thistle
# Saved image stemless_gentian_14_1.jpg and wrote to CSV with label stemless_gentian
# Saved image globe_thistle_14_2.jpg and wrote to CSV with label globe_thistle
# Saved image pink-yellow_dahlia_14_3.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image alpine_sea_holly_14_4.jpg and wrote to CSV with label alpine_sea_holly
# Saved image garden_phlox_14_5.jpg and wrote to CSV with label garden_phlox
# Saved image giant_white_arum_lily_14_6.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image passion_flower_14_7.jpg and wrote to CSV with label passion_flower
# Saved image siam_tulip_14_8.jpg and wrote to CSV with label siam_tulip
# Saved image tree_mallow_14_9.jpg and wrote to CSV with label tree_mallow
# Saved image hippeastrum_14_10.jpg and wrote to CSV with label hippeastrum
# Saved image petunia_14_11.jpg and wrote to CSV with label petunia
# Saved image globe-flower_14_12.jpg and wrote to CSV with label globe-flower
# Saved image bearded_iris_14_13.jpg and wrote to CSV with label bearded_iris
# Saved image mexican_petunia_14_14.jpg and wrote to CSV with label mexican_petunia
# Saved image sweet_pea_14_15.jpg and wrote to CSV with label sweet_pea
# Saved image purple_coneflower_14_16.jpg and wrote to CSV with label purple_coneflower
# Saved image cape_flower_14_17.jpg and wrote to CSV with label cape_flower
# Saved image oxeye_daisy_14_18.jpg and wrote to CSV with label oxeye_daisy
# Saved image sword_lily_14_19.jpg and wrote to CSV with label sword_lily
# Saved image wallflower_14_20.jpg and wrote to CSV with label wallflower
# Saved image cape_flower_14_21.jpg and wrote to CSV with label cape_flower
# Saved image spring_crocus_14_22.jpg and wrote to CSV with label spring_crocus
# Saved image marigold_14_23.jpg and wrote to CSV with label marigold
# Saved image oxeye_daisy_14_24.jpg and wrote to CSV with label oxeye_daisy
# Saved image clematis_14_25.jpg and wrote to CSV with label clematis
# Saved image geranium_14_26.jpg and wrote to CSV with label geranium
# Saved image bougainvillea_14_27.jpg and wrote to CSV with label bougainvillea
# Saved image garden_phlox_14_28.jpg and wrote to CSV with label garden_phlox
# Saved image fritillary_14_29.jpg and wrote to CSV with label fritillary
# Saved image pincushion_flower_14_30.jpg and wrote to CSV with label pincushion_flower
# Saved image foxglove_14_31.jpg and wrote to CSV with label foxglove
# Saved image cape_flower_14_32.jpg and wrote to CSV with label cape_flower
# Saved image daffodil_15_1.jpg and wrote to CSV with label daffodil
# Saved image spear_thistle_15_2.jpg and wrote to CSV with label spear_thistle
# Saved image columbine_15_3.jpg and wrote to CSV with label columbine
# Saved image frangipani_15_4.jpg and wrote to CSV with label frangipani
# Saved image daffodil_15_5.jpg and wrote to CSV with label daffodil
# Saved image lotus_lotus_15_6.jpg and wrote to CSV with label lotus_lotus
# Saved image desert-rose_15_7.jpg and wrote to CSV with label desert-rose
# Saved image garden_phlox_15_8.jpg and wrote to CSV with label garden_phlox
# Saved image ball_moss_15_9.jpg and wrote to CSV with label ball_moss
# Saved image morning_glory_15_10.jpg and wrote to CSV with label morning_glory
# Saved image great_masterwort_15_11.jpg and wrote to CSV with label great_masterwort
# Saved image common_dandelion_15_12.jpg and wrote to CSV with label common_dandelion
# Saved image sword_lily_15_13.jpg and wrote to CSV with label sword_lily
# Saved image peruvian_lily_15_14.jpg and wrote to CSV with label peruvian_lily
# Saved image spear_thistle_15_15.jpg and wrote to CSV with label spear_thistle
# Saved image hard-leaved_pocket_orchid_15_16.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image poinsettia_15_17.jpg and wrote to CSV with label poinsettia
# Saved image windflower_15_18.jpg and wrote to CSV with label windflower
# Saved image balloon_flower_15_19.jpg and wrote to CSV with label balloon_flower
# Saved image petunia_15_20.jpg and wrote to CSV with label petunia
# Saved image gazania_15_21.jpg and wrote to CSV with label gazania
# Saved image passion_flower_15_22.jpg and wrote to CSV with label passion_flower
# Saved image canterbury_bells_15_23.jpg and wrote to CSV with label canterbury_bells
# Saved image artichoke_15_24.jpg and wrote to CSV with label artichoke
# Saved image canna_lily_15_25.jpg and wrote to CSV with label canna_lily
# Saved image orange_dahlia_15_26.jpg and wrote to CSV with label orange_dahlia
# Saved image pelargonium_15_27.jpg and wrote to CSV with label pelargonium
# Saved image passion_flower_15_28.jpg and wrote to CSV with label passion_flower
# Saved image mexican_petunia_15_29.jpg and wrote to CSV with label mexican_petunia
# Saved image petunia_15_30.jpg and wrote to CSV with label petunia
# Saved image petunia_15_31.jpg and wrote to CSV with label petunia
# Saved image water_lily_15_32.jpg and wrote to CSV with label water_lily
# Saved image passion_flower_16_1.jpg and wrote to CSV with label passion_flower
# Saved image grape_hyacinth_16_2.jpg and wrote to CSV with label grape_hyacinth
# Saved image geranium_16_3.jpg and wrote to CSV with label geranium
# Saved image geranium_16_4.jpg and wrote to CSV with label geranium
# Saved image geranium_16_5.jpg and wrote to CSV with label geranium
# Saved image lotus_lotus_16_6.jpg and wrote to CSV with label lotus_lotus
# Saved image cautleya_spicata_16_7.jpg and wrote to CSV with label cautleya_spicata
# Saved image frangipani_16_8.jpg and wrote to CSV with label frangipani
# Saved image ruby-lipped_cattleya_16_9.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image carnation_16_10.jpg and wrote to CSV with label carnation
# Saved image red_ginger_16_11.jpg and wrote to CSV with label red_ginger
# Saved image hippeastrum_16_12.jpg and wrote to CSV with label hippeastrum
# Saved image water_lily_16_13.jpg and wrote to CSV with label water_lily
# Saved image hard-leaved_pocket_orchid_16_14.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image orange_dahlia_16_15.jpg and wrote to CSV with label orange_dahlia
# Saved image thorn_apple_16_16.jpg and wrote to CSV with label thorn_apple
# Saved image poinsettia_16_17.jpg and wrote to CSV with label poinsettia
# Saved image hippeastrum_16_18.jpg and wrote to CSV with label hippeastrum
# Saved image hippeastrum_16_19.jpg and wrote to CSV with label hippeastrum
# Saved image fire_lily_16_20.jpg and wrote to CSV with label fire_lily
# Saved image stemless_gentian_16_21.jpg and wrote to CSV with label stemless_gentian
# Saved image snapdragon_16_22.jpg and wrote to CSV with label snapdragon
# Saved image passion_flower_16_23.jpg and wrote to CSV with label passion_flower
# Saved image thorn_apple_16_24.jpg and wrote to CSV with label thorn_apple
# Saved image pincushion_flower_16_25.jpg and wrote to CSV with label pincushion_flower
# Saved image primula_16_26.jpg and wrote to CSV with label primula
# Saved image pink-yellow_dahlia_16_27.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image buttercup_16_28.jpg and wrote to CSV with label buttercup
# Saved image mallow_16_29.jpg and wrote to CSV with label mallow
# Saved image tree_poppy_16_30.jpg and wrote to CSV with label tree_poppy
# Saved image orange_dahlia_16_31.jpg and wrote to CSV with label orange_dahlia
# Saved image passion_flower_16_32.jpg and wrote to CSV with label passion_flower
# Saved image japanese_anemone_17_1.jpg and wrote to CSV with label japanese_anemone
# Saved image desert-rose_17_2.jpg and wrote to CSV with label desert-rose
# Saved image gaura_17_3.jpg and wrote to CSV with label gaura
# Saved image clematis_17_4.jpg and wrote to CSV with label clematis
# Saved image azalea_17_5.jpg and wrote to CSV with label azalea
# Saved image giant_white_arum_lily_17_6.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image bearded_iris_17_7.jpg and wrote to CSV with label bearded_iris
# Saved image bishop_of_llandaff_17_8.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image cape_flower_17_9.jpg and wrote to CSV with label cape_flower
# Saved image gaura_17_10.jpg and wrote to CSV with label gaura
# Saved image globe_thistle_17_11.jpg and wrote to CSV with label globe_thistle
# Saved image hibiscus_17_12.jpg and wrote to CSV with label hibiscus
# Saved image colt's_foot_17_13.jpg and wrote to CSV with label colt's_foot
# Saved image pelargonium_17_14.jpg and wrote to CSV with label pelargonium
# Saved image globe_thistle_17_15.jpg and wrote to CSV with label globe_thistle
# Saved image hippeastrum_17_16.jpg and wrote to CSV with label hippeastrum
# Saved image hard-leaved_pocket_orchid_17_17.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image clematis_17_18.jpg and wrote to CSV with label clematis
# Saved image canterbury_bells_17_19.jpg and wrote to CSV with label canterbury_bells
# Saved image windflower_17_20.jpg and wrote to CSV with label windflower
# Saved image snapdragon_17_21.jpg and wrote to CSV with label snapdragon
# Saved image cape_flower_17_22.jpg and wrote to CSV with label cape_flower
# Saved image orange_dahlia_17_23.jpg and wrote to CSV with label orange_dahlia
# Saved image ruby-lipped_cattleya_17_24.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image passion_flower_17_25.jpg and wrote to CSV with label passion_flower
# Saved image buttercup_17_26.jpg and wrote to CSV with label buttercup
# Saved image red_ginger_17_27.jpg and wrote to CSV with label red_ginger
# Saved image hippeastrum_17_28.jpg and wrote to CSV with label hippeastrum
# Saved image artichoke_17_29.jpg and wrote to CSV with label artichoke
# Saved image mexican_petunia_17_30.jpg and wrote to CSV with label mexican_petunia
# Saved image corn_poppy_17_31.jpg and wrote to CSV with label corn_poppy
# Saved image bromelia_17_32.jpg and wrote to CSV with label bromelia
# Saved image bishop_of_llandaff_18_1.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image columbine_18_2.jpg and wrote to CSV with label columbine
# Saved image watercress_18_3.jpg and wrote to CSV with label watercress
# Saved image oxeye_daisy_18_4.jpg and wrote to CSV with label oxeye_daisy
# Saved image yellow_iris_18_5.jpg and wrote to CSV with label yellow_iris
# Saved image poinsettia_18_6.jpg and wrote to CSV with label poinsettia
# Saved image ruby-lipped_cattleya_18_7.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image pink_primrose_18_8.jpg and wrote to CSV with label pink_primrose
# Saved image tiger_lily_18_9.jpg and wrote to CSV with label tiger_lily
# Saved image wallflower_18_10.jpg and wrote to CSV with label wallflower
# Saved image carnation_18_11.jpg and wrote to CSV with label carnation
# Saved image wallflower_18_12.jpg and wrote to CSV with label wallflower
# Saved image pincushion_flower_18_13.jpg and wrote to CSV with label pincushion_flower
# Saved image toad_lily_18_14.jpg and wrote to CSV with label toad_lily
# Saved image hibiscus_18_15.jpg and wrote to CSV with label hibiscus
# Saved image bird_of_paradise_18_16.jpg and wrote to CSV with label bird_of_paradise
# Saved image azalea_18_17.jpg and wrote to CSV with label azalea
# Saved image artichoke_18_18.jpg and wrote to CSV with label artichoke
# Saved image barbeton_daisy_18_19.jpg and wrote to CSV with label barbeton_daisy
# Saved image mallow_18_20.jpg and wrote to CSV with label mallow
# Saved image alpine_sea_holly_18_21.jpg and wrote to CSV with label alpine_sea_holly
# Saved image mallow_18_22.jpg and wrote to CSV with label mallow
# Saved image fritillary_18_23.jpg and wrote to CSV with label fritillary
# Saved image bougainvillea_18_24.jpg and wrote to CSV with label bougainvillea
# Saved image osteospermum_18_25.jpg and wrote to CSV with label osteospermum
# Saved image camellia_18_26.jpg and wrote to CSV with label camellia
# Saved image primula_18_27.jpg and wrote to CSV with label primula
# Saved image cape_flower_18_28.jpg and wrote to CSV with label cape_flower
# Saved image azalea_18_29.jpg and wrote to CSV with label azalea
# Saved image hibiscus_18_30.jpg and wrote to CSV with label hibiscus
# Saved image giant_white_arum_lily_18_31.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image bearded_iris_18_32.jpg and wrote to CSV with label bearded_iris
# Saved image rose_19_1.jpg and wrote to CSV with label rose
# Saved image giant_white_arum_lily_19_2.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image mexican_petunia_19_3.jpg and wrote to CSV with label mexican_petunia
# Saved image moon_orchid_19_4.jpg and wrote to CSV with label moon_orchid
# Saved image magnolia_19_5.jpg and wrote to CSV with label magnolia
# Saved image english_marigold_19_6.jpg and wrote to CSV with label english_marigold
# Saved image japanese_anemone_19_7.jpg and wrote to CSV with label japanese_anemone
# Saved image morning_glory_19_8.jpg and wrote to CSV with label morning_glory
# Saved image pink_primrose_19_9.jpg and wrote to CSV with label pink_primrose
# Saved image spring_crocus_19_10.jpg and wrote to CSV with label spring_crocus
# Saved image wallflower_19_11.jpg and wrote to CSV with label wallflower
# Saved image english_marigold_19_12.jpg and wrote to CSV with label english_marigold
# Saved image bee_balm_19_13.jpg and wrote to CSV with label bee_balm
# Saved image blackberry_lily_19_14.jpg and wrote to CSV with label blackberry_lily
# Saved image bishop_of_llandaff_19_15.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image frangipani_19_16.jpg and wrote to CSV with label frangipani
# Saved image peruvian_lily_19_17.jpg and wrote to CSV with label peruvian_lily
# Saved image desert-rose_19_18.jpg and wrote to CSV with label desert-rose
# Saved image tree_poppy_19_19.jpg and wrote to CSV with label tree_poppy
# Saved image silverbush_19_20.jpg and wrote to CSV with label silverbush
# Saved image gazania_19_21.jpg and wrote to CSV with label gazania
# Saved image english_marigold_19_22.jpg and wrote to CSV with label english_marigold
# Saved image hibiscus_19_23.jpg and wrote to CSV with label hibiscus
# Saved image barbeton_daisy_19_24.jpg and wrote to CSV with label barbeton_daisy
# Saved image japanese_anemone_19_25.jpg and wrote to CSV with label japanese_anemone
# Saved image barbeton_daisy_19_26.jpg and wrote to CSV with label barbeton_daisy
# Saved image barbeton_daisy_19_27.jpg and wrote to CSV with label barbeton_daisy
# Saved image magnolia_19_28.jpg and wrote to CSV with label magnolia
# Saved image spear_thistle_19_29.jpg and wrote to CSV with label spear_thistle
# Saved image frangipani_19_30.jpg and wrote to CSV with label frangipani
# Saved image water_lily_19_31.jpg and wrote to CSV with label water_lily
# Saved image pink_primrose_19_32.jpg and wrote to CSV with label pink_primrose
# Saved image poinsettia_20_1.jpg and wrote to CSV with label poinsettia
# Saved image prince_of_wales_feathers_20_2.jpg and wrote to CSV with label prince_of_wales_feathers
# Saved image geranium_20_3.jpg and wrote to CSV with label geranium
# Saved image pincushion_flower_20_4.jpg and wrote to CSV with label pincushion_flower
# Saved image poinsettia_20_5.jpg and wrote to CSV with label poinsettia
# Saved image wallflower_20_6.jpg and wrote to CSV with label wallflower
# Saved image petunia_20_7.jpg and wrote to CSV with label petunia
# Saved image passion_flower_20_8.jpg and wrote to CSV with label passion_flower
# ...
# Saved image artichoke_198_9.jpg and wrote to CSV with label artichoke
# Saved image pelargonium_198_10.jpg and wrote to CSV with label pelargonium
# Saved image primula_198_11.jpg and wrote to CSV with label primula
# Saved image yellow_iris_198_12.jpg and wrote to CSV with label yellow_iris
# Saved image californian_poppy_198_13.jpg and wrote to CSV with label californian_poppy
# Saved image passion_flower_198_14.jpg and wrote to CSV with label passion_flower
# Saved image fire_lily_198_15.jpg and wrote to CSV with label fire_lily
# Saved image lotus_lotus_198_16.jpg and wrote to CSV with label lotus_lotus
# Saved image love_in_the_mist_198_17.jpg and wrote to CSV with label love_in_the_mist
# Saved image mallow_198_18.jpg and wrote to CSV with label mallow
# Saved image pincushion_flower_198_19.jpg and wrote to CSV with label pincushion_flower
# Saved image toad_lily_198_20.jpg and wrote to CSV with label toad_lily
# Saved image petunia_198_21.jpg and wrote to CSV with label petunia
# Saved image bishop_of_llandaff_198_22.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image stemless_gentian_198_23.jpg and wrote to CSV with label stemless_gentian
# Saved image wild_pansy_198_24.jpg and wrote to CSV with label wild_pansy
# Saved image bird_of_paradise_198_25.jpg and wrote to CSV with label bird_of_paradise
# Saved image trumpet_creeper_198_26.jpg and wrote to CSV with label trumpet_creeper
# Saved image daffodil_198_27.jpg and wrote to CSV with label daffodil
# Saved image bougainvillea_198_28.jpg and wrote to CSV with label bougainvillea
# Saved image garden_phlox_198_29.jpg and wrote to CSV with label garden_phlox
# Saved image ball_moss_198_30.jpg and wrote to CSV with label ball_moss
# Saved image gaura_198_31.jpg and wrote to CSV with label gaura
# Saved image ruby-lipped_cattleya_198_32.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image trumpet_creeper_199_1.jpg and wrote to CSV with label trumpet_creeper
# Saved image sweet_pea_199_2.jpg and wrote to CSV with label sweet_pea
# Saved image ruby-lipped_cattleya_199_3.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image wild_pansy_199_4.jpg and wrote to CSV with label wild_pansy
# Saved image cape_flower_199_5.jpg and wrote to CSV with label cape_flower
# Saved image rose_199_6.jpg and wrote to CSV with label rose
# Saved image tree_mallow_199_7.jpg and wrote to CSV with label tree_mallow
# Saved image cape_flower_199_8.jpg and wrote to CSV with label cape_flower
# Saved image hard-leaved_pocket_orchid_199_9.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image tiger_lily_199_10.jpg and wrote to CSV with label tiger_lily
# Saved image frangipani_199_11.jpg and wrote to CSV with label frangipani
# Saved image globe-flower_199_12.jpg and wrote to CSV with label globe-flower
# Saved image camellia_199_13.jpg and wrote to CSV with label camellia
# Saved image marigold_199_14.jpg and wrote to CSV with label marigold
# Saved image frangipani_199_15.jpg and wrote to CSV with label frangipani
# Saved image tree_mallow_199_16.jpg and wrote to CSV with label tree_mallow
# Saved image wallflower_199_17.jpg and wrote to CSV with label wallflower
# Saved image water_lily_199_18.jpg and wrote to CSV with label water_lily
# Saved image wallflower_199_19.jpg and wrote to CSV with label wallflower
# Saved image globe_thistle_199_20.jpg and wrote to CSV with label globe_thistle
# Saved image wallflower_199_21.jpg and wrote to CSV with label wallflower
# Saved image pink-yellow_dahlia_199_22.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image globe-flower_199_23.jpg and wrote to CSV with label globe-flower
# Saved image japanese_anemone_199_24.jpg and wrote to CSV with label japanese_anemone
# Saved image bearded_iris_199_25.jpg and wrote to CSV with label bearded_iris
# Saved image bishop_of_llandaff_199_26.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image pink_primrose_199_27.jpg and wrote to CSV with label pink_primrose
# Saved image barbeton_daisy_199_28.jpg and wrote to CSV with label barbeton_daisy
# Saved image rose_199_29.jpg and wrote to CSV with label rose
# Saved image lenten_rose_199_30.jpg and wrote to CSV with label lenten_rose
# Saved image pink-yellow_dahlia_199_31.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image frangipani_199_32.jpg and wrote to CSV with label frangipani
# Saved image moon_orchid_200_1.jpg and wrote to CSV with label moon_orchid
# Saved image petunia_200_2.jpg and wrote to CSV with label petunia
# Saved image passion_flower_200_3.jpg and wrote to CSV with label passion_flower
# Saved image prince_of_wales_feathers_200_4.jpg and wrote to CSV with label prince_of_wales_feathers
# Saved image globe_thistle_200_5.jpg and wrote to CSV with label globe_thistle
# Saved image passion_flower_200_6.jpg and wrote to CSV with label passion_flower
# Saved image wild_pansy_200_7.jpg and wrote to CSV with label wild_pansy
# Saved image oxeye_daisy_200_8.jpg and wrote to CSV with label oxeye_daisy
# Saved image colt's_foot_200_9.jpg and wrote to CSV with label colt's_foot
# Saved image lotus_lotus_200_10.jpg and wrote to CSV with label lotus_lotus
# Saved image osteospermum_200_11.jpg and wrote to CSV with label osteospermum
# Saved image colt's_foot_200_12.jpg and wrote to CSV with label colt's_foot
# Saved image pincushion_flower_200_13.jpg and wrote to CSV with label pincushion_flower
# Saved image snapdragon_200_14.jpg and wrote to CSV with label snapdragon
# Saved image primula_200_15.jpg and wrote to CSV with label primula
# Saved image californian_poppy_200_16.jpg and wrote to CSV with label californian_poppy
# Saved image giant_white_arum_lily_200_17.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image yellow_iris_200_18.jpg and wrote to CSV with label yellow_iris
# Saved image purple_coneflower_200_19.jpg and wrote to CSV with label purple_coneflower
# Saved image sword_lily_200_20.jpg and wrote to CSV with label sword_lily
# Saved image cape_flower_200_21.jpg and wrote to CSV with label cape_flower
# Saved image hard-leaved_pocket_orchid_200_22.jpg and wrote to CSV with label hard-leaved_pocket_orchid
# Saved image petunia_200_23.jpg and wrote to CSV with label petunia
# Saved image hibiscus_200_24.jpg and wrote to CSV with label hibiscus
# Saved image great_masterwort_200_25.jpg and wrote to CSV with label great_masterwort
# Saved image pink-yellow_dahlia_200_26.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image morning_glory_200_27.jpg and wrote to CSV with label morning_glory
# Saved image pelargonium_200_28.jpg and wrote to CSV with label pelargonium
# Saved image carnation_200_29.jpg and wrote to CSV with label carnation
# Saved image bee_balm_200_30.jpg and wrote to CSV with label bee_balm
# Saved image black-eyed_susan_200_31.jpg and wrote to CSV with label black-eyed_susan
# Saved image yellow_iris_200_32.jpg and wrote to CSV with label yellow_iris
# Saved image watercress_201_1.jpg and wrote to CSV with label watercress
# Saved image common_dandelion_201_2.jpg and wrote to CSV with label common_dandelion
# Saved image toad_lily_201_3.jpg and wrote to CSV with label toad_lily
# Saved image blanket_flower_201_4.jpg and wrote to CSV with label blanket_flower
# Saved image hibiscus_201_5.jpg and wrote to CSV with label hibiscus
# Saved image petunia_201_6.jpg and wrote to CSV with label petunia
# Saved image giant_white_arum_lily_201_7.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image cyclamen_201_8.jpg and wrote to CSV with label cyclamen
# Saved image desert-rose_201_9.jpg and wrote to CSV with label desert-rose
# Saved image pelargonium_201_10.jpg and wrote to CSV with label pelargonium
# Saved image windflower_201_11.jpg and wrote to CSV with label windflower
# Saved image windflower_201_12.jpg and wrote to CSV with label windflower
# Saved image frangipani_201_13.jpg and wrote to CSV with label frangipani
# Saved image bromelia_201_14.jpg and wrote to CSV with label bromelia
# Saved image barbeton_daisy_201_15.jpg and wrote to CSV with label barbeton_daisy
# Saved image pelargonium_201_16.jpg and wrote to CSV with label pelargonium
# Saved image magnolia_201_17.jpg and wrote to CSV with label magnolia
# Saved image pelargonium_201_18.jpg and wrote to CSV with label pelargonium
# Saved image cape_flower_201_19.jpg and wrote to CSV with label cape_flower
# Saved image bougainvillea_201_20.jpg and wrote to CSV with label bougainvillea
# Saved image windflower_201_21.jpg and wrote to CSV with label windflower
# Saved image wild_pansy_201_22.jpg and wrote to CSV with label wild_pansy
# Saved image wallflower_201_23.jpg and wrote to CSV with label wallflower
# Saved image giant_white_arum_lily_201_24.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image pink-yellow_dahlia_201_25.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image primula_201_26.jpg and wrote to CSV with label primula
# Saved image marigold_201_27.jpg and wrote to CSV with label marigold
# Saved image tree_poppy_201_28.jpg and wrote to CSV with label tree_poppy
# Saved image daffodil_201_29.jpg and wrote to CSV with label daffodil
# Saved image carnation_201_30.jpg and wrote to CSV with label carnation
# Saved image geranium_201_31.jpg and wrote to CSV with label geranium
# Saved image bolero_deep_blue_201_32.jpg and wrote to CSV with label bolero_deep_blue
# Saved image wallflower_202_1.jpg and wrote to CSV with label wallflower
# Saved image bishop_of_llandaff_202_2.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image yellow_iris_202_3.jpg and wrote to CSV with label yellow_iris
# Saved image wallflower_202_4.jpg and wrote to CSV with label wallflower
# Saved image pincushion_flower_202_5.jpg and wrote to CSV with label pincushion_flower
# Saved image anthurium_202_6.jpg and wrote to CSV with label anthurium
# Saved image orange_dahlia_202_7.jpg and wrote to CSV with label orange_dahlia
# Saved image pink-yellow_dahlia_202_8.jpg and wrote to CSV with label pink-yellow_dahlia
# Saved image geranium_202_9.jpg and wrote to CSV with label geranium
# Saved image californian_poppy_202_10.jpg and wrote to CSV with label californian_poppy
# Saved image watercress_202_11.jpg and wrote to CSV with label watercress
# Saved image yellow_iris_202_12.jpg and wrote to CSV with label yellow_iris
# Saved image barbeton_daisy_202_13.jpg and wrote to CSV with label barbeton_daisy
# Saved image orange_dahlia_202_14.jpg and wrote to CSV with label orange_dahlia
# Saved image sword_lily_202_15.jpg and wrote to CSV with label sword_lily
# Saved image mexican_petunia_202_16.jpg and wrote to CSV with label mexican_petunia
# Saved image frangipani_202_17.jpg and wrote to CSV with label frangipani
# Saved image red_ginger_202_18.jpg and wrote to CSV with label red_ginger
# Saved image californian_poppy_202_19.jpg and wrote to CSV with label californian_poppy
# Saved image canna_lily_202_20.jpg and wrote to CSV with label canna_lily
# Saved image marigold_202_21.jpg and wrote to CSV with label marigold
# Saved image purple_coneflower_202_22.jpg and wrote to CSV with label purple_coneflower
# Saved image english_marigold_202_23.jpg and wrote to CSV with label english_marigold
# Saved image camellia_202_24.jpg and wrote to CSV with label camellia
# Saved image gazania_202_25.jpg and wrote to CSV with label gazania
# Saved image petunia_202_26.jpg and wrote to CSV with label petunia
# Saved image wild_pansy_202_27.jpg and wrote to CSV with label wild_pansy
# Saved image colt's_foot_202_28.jpg and wrote to CSV with label colt's_foot
# Saved image tree_mallow_202_29.jpg and wrote to CSV with label tree_mallow
# Saved image barbeton_daisy_202_30.jpg and wrote to CSV with label barbeton_daisy
# Saved image passion_flower_202_31.jpg and wrote to CSV with label passion_flower
# Saved image californian_poppy_202_32.jpg and wrote to CSV with label californian_poppy
# Saved image barbeton_daisy_203_1.jpg and wrote to CSV with label barbeton_daisy
# Saved image sword_lily_203_2.jpg and wrote to CSV with label sword_lily
# Saved image geranium_203_3.jpg and wrote to CSV with label geranium
# Saved image watercress_203_4.jpg and wrote to CSV with label watercress
# Saved image hibiscus_203_5.jpg and wrote to CSV with label hibiscus
# Saved image daffodil_203_6.jpg and wrote to CSV with label daffodil
# Saved image blanket_flower_203_7.jpg and wrote to CSV with label blanket_flower
# Saved image camellia_203_8.jpg and wrote to CSV with label camellia
# Saved image hippeastrum_203_9.jpg and wrote to CSV with label hippeastrum
# Saved image pelargonium_203_10.jpg and wrote to CSV with label pelargonium
# Saved image bird_of_paradise_203_11.jpg and wrote to CSV with label bird_of_paradise
# Saved image stemless_gentian_203_12.jpg and wrote to CSV with label stemless_gentian
# Saved image canterbury_bells_203_13.jpg and wrote to CSV with label canterbury_bells
# Saved image blanket_flower_203_14.jpg and wrote to CSV with label blanket_flower
# Saved image bird_of_paradise_203_15.jpg and wrote to CSV with label bird_of_paradise
# Saved image tiger_lily_203_16.jpg and wrote to CSV with label tiger_lily
# Saved image water_lily_203_17.jpg and wrote to CSV with label water_lily
# Saved image spear_thistle_203_18.jpg and wrote to CSV with label spear_thistle
# Saved image morning_glory_203_19.jpg and wrote to CSV with label morning_glory
# Saved image spear_thistle_203_20.jpg and wrote to CSV with label spear_thistle
# Saved image daffodil_203_21.jpg and wrote to CSV with label daffodil
# Saved image bee_balm_203_22.jpg and wrote to CSV with label bee_balm
# Saved image magnolia_203_23.jpg and wrote to CSV with label magnolia
# Saved image purple_coneflower_203_24.jpg and wrote to CSV with label purple_coneflower
# Saved image sweet_pea_204_1.jpg and wrote to CSV with label sweet_pea
# Saved image clematis_204_2.jpg and wrote to CSV with label clematis
# Saved image king_protea_204_3.jpg and wrote to CSV with label king_protea
# Saved image geranium_204_4.jpg and wrote to CSV with label geranium
# Saved image desert-rose_204_5.jpg and wrote to CSV with label desert-rose
# Saved image passion_flower_204_6.jpg and wrote to CSV with label passion_flower
# Saved image grape_hyacinth_204_7.jpg and wrote to CSV with label grape_hyacinth
# Saved image bishop_of_llandaff_204_8.jpg and wrote to CSV with label bishop_of_llandaff
# Saved image tiger_lily_204_9.jpg and wrote to CSV with label tiger_lily
# Saved image rose_204_10.jpg and wrote to CSV with label rose
# Saved image frangipani_204_11.jpg and wrote to CSV with label frangipani
# Saved image ruby-lipped_cattleya_204_12.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image ruby-lipped_cattleya_204_13.jpg and wrote to CSV with label ruby-lipped_cattleya
# Saved image foxglove_204_14.jpg and wrote to CSV with label foxglove
# Saved image great_masterwort_204_15.jpg and wrote to CSV with label great_masterwort
# Saved image morning_glory_204_16.jpg and wrote to CSV with label morning_glory
# Saved image water_lily_204_17.jpg and wrote to CSV with label water_lily
# Saved image cautleya_spicata_204_18.jpg and wrote to CSV with label cautleya_spicata
# Saved image buttercup_204_19.jpg and wrote to CSV with label buttercup
# Saved image thorn_apple_204_20.jpg and wrote to CSV with label thorn_apple
# Saved image watercress_204_21.jpg and wrote to CSV with label watercress
# Saved image lotus_lotus_204_22.jpg and wrote to CSV with label lotus_lotus
# Saved image passion_flower_204_23.jpg and wrote to CSV with label passion_flower
# Saved image californian_poppy_204_24.jpg and wrote to CSV with label californian_poppy
# Saved image foxglove_204_25.jpg and wrote to CSV with label foxglove
# Saved image pink_primrose_204_26.jpg and wrote to CSV with label pink_primrose
# Saved image giant_white_arum_lily_204_27.jpg and wrote to CSV with label giant_white_arum_lily
# Saved image sunflower_204_28.jpg and wrote to CSV with label sunflower
# Saved image spear_thistle_204_29.jpg and wrote to CSV with label spear_thistle
# Saved image balloon_flower_204_30.jpg and wrote to CSV with label balloon_flower
# Saved image hibiscus_204_31.jpg and wrote to CSV with label hibiscus
# Saved image sword_lily_204_32.jpg and wrote to CSV with label sword_lily
